# %%
pip install langchain-core langchain-google-genai langgraph sentence-transformers neo4j langchain-community numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-core in c:\users\kedar\appdata\roaming\python\python313\site-packages (1.2.7)
# Requirement already satisfied: langchain-google-genai in c:\users\kedar\appdata\roaming\python\python313\site-packages (4.2.0)
# Requirement already satisfied: langgraph in c:\users\kedar\appdata\roaming\python\python313\site-packages (1.0.7)
# Requirement already satisfied: sentence-transformers in c:\users\kedar\appdata\roaming\python\python313\site-packages (5.2.2)
# Collecting neo4j
#   Downloading neo4j-6.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: langchain-community in c:\users\kedar\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: numpy in c:\users\kedar\appdata\roaming\python\python313\site-packages (2.4.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (0.6.5)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.12.0)
# Requirement already satisfied: certifi in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-google-genai) (1.61.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.48.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\kedar\appdata\roaming\python\python313\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (46.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from sentence-transformers) (2.10.0+cu126)
# Requirement already satisfied: scikit-learn in c:\users\kedar\appdata\roaming\python\python313\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\kedar\appdata\roaming\python\python313\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: tqdm in c:\users\kedar\appdata\roaming\python\python313\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: filelock in c:\users\kedar\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.1.0)
# Requirement already satisfied: pytz in c:\users\kedar\appdata\roaming\python\python313\site-packages (from neo4j) (2025.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: greenlet>=1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kedar\appdata\roaming\python\python313\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.23)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\kedar\appdata\roaming\python\python313\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kedar\appdata\roaming\python\python313\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Downloading neo4j-6.1.0-py3-none-any.whl (325 kB)
# Installing collected packages: neo4j
# Successfully installed neo4j-6.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain-groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-groq in c:\users\kedar\appdata\roaming\python\python313\site-packages (1.1.1)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-groq) (1.2.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\kedar\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.6.5)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install neo4j
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: neo4j in c:\users\kedar\appdata\roaming\python\python313\site-packages (6.1.0)
# Requirement already satisfied: pytz in c:\users\kedar\appdata\roaming\python\python313\site-packages (from neo4j) (2025.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython-autotime) (9.8.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from ipython->ipython-autotime) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\kedar\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-autotime) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython->ipython-autotime) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython->ipython-autotime) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\kedar\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython->ipython-autotime) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\kedar\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython->ipython-autotime) (0.2.3)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.3.2
# time: 70.6 μs (started: 2026-03-23 22:43:00 +05:30)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.memory import MemorySaver
from langgraph.types import interrupt
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from sentence_transformers import SentenceTransformer
from neo4j import GraphDatabase
from typing import TypedDict, Annotated
import numpy as np
import uuid
import os
# Out:
# time: 31.5 s (started: 2026-03-23 22:43:00 +05:30)

# %%
embedder = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# time: 6.26 s (started: 2026-03-23 22:43:32 +05:30)

# %%
from google.colab import userdata
api_go = userdata.get("Gemini")
api_gr = userdata.get("groqAPi")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from google.colab import userdata
#       2 api_go = userdata.get("Gemini")
#       3 api_gr = userdata.get("groqAPi")
#
# ModuleNotFoundError: No module named 'google.colab'
# time: 82.3 ms (started: 2026-03-23 22:43:38 +05:30)

# %%
conv = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash-lite",
    temperature = 0.2,
    google_api_key = api_go
)

speed = ChatGroq(
    model = "llama-3.3-70b-versatile",
    temperature = 0,
    groq_api_key = api_gr
)
# Out:
# time: 1.24 s (started: 2026-03-21 11:05:47 +00:00)

# %% [markdown]
# ### Relevancy tool

# %%
@tool
def relevancy_ebd(player_message: str, recent_context: str) -> str:
    """
  When to call: before passing any player message to an NPC or
                taking any game action

  player_message: the exact text the player just sent

  recent_context: one sentence summarising the last 2 exchanges,
                  or "no prior context" if this is the first message

  output: yes if the player message is relevant to the recent context,
          no otherwise
    """
    embedding_player = embedder.encode(player_message)
    embedding_context = embedder.encode(recent_context)
    dot= np.dot(embedding_player, embedding_context) / (np.linalg.norm(embedding_player) * np.linalg.norm(embedding_context))
    if dot > 0.5:
        return f"yes \n dot value: {dot}"
    else:
        return f"no \n dot value: {dot}"
# Out:
# time: 14.5 ms (started: 2026-03-21 11:05:48 +00:00)

# %%
@tool
def relevancy_llm(player_message: str, recent_context: str) -> str:
    """
  When to call: before passing any player message to an NPC or
                taking any game action

  player_message: the exact text the player just sent

  recent_context: one sentence summarising the last 2 exchanges,
                  or "no prior context" if this is the first message

  output: yes if the player message is relevant to the recent context,
          no otherwise
    """
    prompt = f"""You are a very experienced context manager
    you have to figure out based on previous discussion of the player with npc whether the current message is relevant or the player is just messing about

    here is the player message: {player_message}

    here is the recent context: {recent_context}

    STRICT OUTPUT CONDITION: only "yes" if the player message is relevant to the recent context,
          "no" otherwise, no justification or any other text
    """
    return speed.invoke(prompt)
# Out:
# time: 11.4 ms (started: 2026-03-21 11:05:48 +00:00)

# %%
player_message = "We saw the missing page near the fireplace half burnt, it was near the table you were studying"
recent_context = "Where were you?\nI was in the study room\nDo you know about page 42?\nno, i saw the missing page when i entered thorne's room"
# Out:
# time: 723 µs (started: 2026-03-21 11:05:48 +00:00)

# %%
# %%time
ans = relevancy_llm.invoke({"player_message": player_message, "recent_context" : recent_context})
print(ans.content)
# Out:
# yes
# CPU times: user 62.6 ms, sys: 7.96 ms, total: 70.6 ms
# Wall time: 409 ms
# time: 410 ms (started: 2026-03-21 11:05:48 +00:00)

# %%
# %%time
ans = ans = relevancy_ebd.invoke({"player_message": player_message, "recent_context" : recent_context})
print(ans)
# Out:
# yes
#  dot value: 0.6400977969169617
# CPU times: user 101 ms, sys: 10.5 ms, total: 112 ms
# Wall time: 556 ms
# time: 561 ms (started: 2026-03-21 11:05:49 +00:00)

# %% [markdown]
# ### LIE DETECTION

# %%
import requests
import json

@tool
def detect_lie(
    player_message: str,
    lies_told: str,        # JSON string from state["npc_states"][npc_id]["lies_told"]
    lies_caught: str,      # JSON string from state["npc_states"][npc_id]["lies_caught"]
    evidence_found: str,   # JSON string from state["evidence_found"]
) -> str:
    """Detect if the player has caught an NPC in a lie.
    Call this after every converse_npc call.
    
    INPUTS:
    player_message: LAST message by the user
    lies_told: pass npc_states[npc_id]['lies_told'] as JSON string.
    lies_caught: pass npc_states[npc_id]['lies_caught'] as JSON string.
    evidence_found: pass the evidence_found list as JSON string."""

    prompt = f"""<s>[INST]
You are a lie detection system for a murder mystery game. 
Respond in JSON only. No explanation. No extra text.

PLAYER MESSAGE:
{player_message}

LIES THE NPC HAS TOLD:
{json.dumps(lies_told, indent=2)}

LIES ALREADY CAUGHT:
{lies_caught}

EVIDENCE THE PLAYER HAS FOUND:
{evidence_found}

TASK:
Determine if the player's message has caught or challenged any of the NPC's lies.
A lie is caught if the player references evidence or information that directly contradicts it.

Respond with exactly this JSON structure:
{{
  "lie_caught": true or false,
  "topic": "the key from lies_told that was caught, or null",
  "reason": "one sentence explanation"
}}
[/INST]"""

    raw = speed.invoke(prompt)

    try:
        start = raw.find("{")
        end = raw.rfind("}") + 1
        return raw[start:end]   # return JSON string — tool must return string
    except Exception:
        return json.dumps({"lie_caught": False, "topic": None, "reason": "parse error"})

# %%
player_message = "But I found a receipt showing you were at the cafe at 9 PM. You said you were home."

lies_told = json.dumps({
    "alibi": "I was at home all evening.",
    "relationship_with_victim": "I barely knew the victim."
})

lies_caught = json.dumps([])

evidence_found = json.dumps([
    {
        "name": "Cafe Receipt",
        "description": "Receipt timestamped 9:02 PM from Bluebird Cafe with NPC's name."
    }
])

# %%
ans = detect_lie.invoke({"player_message": player_message, "lies_told": lies_told, "lies_caught": lies_caught, "evidence_found": evidence_found})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ans = detect_lie.invoke({"player_message": player_message, "lies_told": lies_told, "lies_caught": lies_caught, "evidence_found": evidence_found})
#
# NameError: name 'detect_lie' is not defined

# %% [markdown]
# ### Summary TOOL

# %%
from __future__ import annotations
import json, re, textwrap
import anthropic
from langchain_core.tools import tool

_MODEL = "claude-sonnet-4-20250514"
_MAX_TOKENS = 900
_CANON_CAP = 60
_SUMMARY_CAP = 500

_client = anthropic.Anthropic()

_SYSTEM = textwrap.dedent("""
You are a strict NPC memory processor for a detective game.

MEMORY:
1. CANON → atomic, past tense, no duplicates, no contradictions
2. SUMMARY:
   - behavior (≤ 80 chars)
   - topics (new only)
   - key_context (≤ 450 chars)

If contradiction → DO NOT add to canon → mark in summary with [CONTRADICTION]

OUTPUT STRICT JSON:
{
  "new_canon_facts": ["..."],
  "updated_summary": {
    "behavior": "...",
    "topics": ["..."],
    "key_context": "..."
  }
}
""").strip()


@tool
def npc_memory_tool(npc_id: str, session_id: str, player_id: str, payload: dict) -> dict:

    if not isinstance(payload, dict):
        return {"status": "error", "error": "payload must be dict", "data": {}}

    if "db" not in payload:
        return {"status": "error", "error": "db missing", "data": {}}

    mode = payload.get("mode")
    if mode not in ("read", "update"):
        return {"status": "error", "error": "invalid mode", "data": {}}

    db = dict(payload["db"])

    record = db.get(npc_id, {})
    canon = record.get("canon", [])
    summary = record.get("summary", {"behavior": "", "topics": [], "key_context": ""})

    if mode == "read":
        return {
            "status": "ok",
            "data": {
                "npc_id": npc_id,
                "canon": canon,
                "summary": summary
            },
            "error": None
        }

    conversation = payload.get("latest_conversation", "").strip()
    if not conversation:
        return {"status": "error", "error": "missing conversation", "data": {}}

    try:
        parsed: dict = {}

        response = _client.messages.create(
            model=_MODEL,
            max_tokens=_MAX_TOKENS,
            system=_SYSTEM,
            messages=[{
                "role": "user",
                "content": json.dumps({
                    "npc": npc_id,
                    "existing_canon": canon,
                    "current_summary": summary,
                    "latest_conversation": conversation
                }, ensure_ascii=False)
            }]
        )

        raw = "".join(b.text for b in response.content if hasattr(b, "text")).strip()

        start = raw.find("{")
        if start == -1:
            raise ValueError("No JSON")

        depth, in_str, esc = 0, False, False
        for i in range(start, len(raw)):
            ch = raw[i]
            if esc:
                esc = False
                continue
            if ch == "\\" and in_str:
                esc = True
                continue
            if ch == '"':
                in_str = not in_str
                continue
            if in_str:
                continue
            if ch == "{":
                depth += 1
            elif ch == "}":
                depth -= 1
                if depth == 0:
                    parsed = json.loads(raw[start:i+1])
                    break

        def norm(x: str) -> str:
            return re.sub(r"[^\w\s]", "", x.lower())

        existing = {norm(f): f for f in canon}
        for f in parsed.get("new_canon_facts", []):
            k = norm(f)
            if k not in existing:
                existing[k] = f

        new_canon = list(existing.values())[-_CANON_CAP:]

        s = parsed.get("updated_summary", {})

        topics_raw = s.get("topics", [])
        if isinstance(topics_raw, str):
            topics_raw = [topics_raw]

        topics = list(dict.fromkeys(topics_raw))

        behavior = str(s.get("behavior", summary.get("behavior", "")))[:80]
        kc = str(s.get("key_context", summary.get("key_context", "")))

        if len(kc) > _SUMMARY_CAP:
            kc = kc[:_SUMMARY_CAP].rstrip() + "…"

        new_summary = {
            "behavior": behavior,
            "topics": topics,
            "key_context": kc
        }

        db[npc_id] = {
            "canon": new_canon,
            "summary": new_summary
        }

        return {
            "status": "ok",
            "data": {
                "db": db,
                "new_facts": parsed.get("new_canon_facts", []),
                "summary": new_summary,
                "facts_added": len(new_canon) - len(canon)
            },
            "error": None
        }

    except Exception as e:
        return {
            "status": "ok",
            "data": {
                "db": db,
                "new_facts": [],
                "summary": summary,
                "_warning": str(e)
            },
            "error": None
        }


MEMORY_TOOLS = [npc_memory_tool]
# Out:
# time: 7.32 ms (started: 2026-03-21 11:09:04 +00:00)

# %% [markdown]
# ### TO DB

# %%
@tool
def send_to_db(npc_id: str, npc_name: str, player_id: str, summary: str) -> dict:
  """"
  send the summary to the db
  """
  payload = {
        "npc_id": npc_id,
        "npc_name": npc_name,
        "player_id": player_id,
        "summary": summary
    }

  print(json.dumps(payload, indent=2))
  return {"status": "success", "npc_id": npc_id}
# Out:
# time: 18.2 ms (started: 2026-03-21 11:38:42 +00:00)

# %% [markdown]
# ### DB

# %%
from neo4j import GraphDatabase
# Out:
# time: 426 µs (started: 2026-03-21 11:39:06 +00:00)

# %%
uri = "neo4j+s://b552bc3b.databases.neo4j.io"
username = "b552bc3b"
password = "294ZpP_BINKAMsXOOSayjtazWYttjiqqGKiDKspE_xw"

driver = GraphDatabase.driver(uri, auth=(username, password))

# Test the connection
try:
    driver.verify_connectivity()
    print("Neo4j database connection successful!")
except Exception as e:
    print(f"Neo4j database connection failed: {e}")
# Out:
# Neo4j database connection successful!
# time: 2.09 s (started: 2026-03-21 11:49:01 +00:00)

# %%
import json

def load_neo4j_config_from_file(file_path):
    with open(file_path, 'r') as f:
        config = json.load(f)
    return config['uri'], config['username'], config['password']
# Out:
# time: 727 µs (started: 2026-03-21 11:45:57 +00:00)

# %%
# Assuming your config file is named 'neo4j_config.json' and is in the same directory
# You might need to upload this file to your Colab environment
config_file_path = 'neo4j_config.json'

try:
    uri, username, password = load_neo4j_config_from_file(config_file_path)
except FileNotFoundError:
    print(f"Error: Configuration file '{config_file_path}' not found. Please create it.")
    # Fallback to placeholders if file not found, or raise an error to stop execution
    uri = "neo4j+s://your_auradb_instance.databases.neo4j.io" # Replace with your actual URI
    username = "neo4j"
    password = "your_auradb_password" # Replace with your actual password
except KeyError as e:
    print(f"Error: Missing key in '{config_file_path}': {e}. Please ensure 'uri', 'username', and 'password' are present.")
    uri = "neo4j+s://your_auradb_instance.databases.neo4j.io" # Replace with your actual URI
    username = "neo4j"
    password = "your_auradb_password" # Replace with your actual password

driver = GraphDatabase.driver(uri, auth=(username, password))

# Test the connection
try:
    driver.verify_connectivity()
    print("Neo4j database connection successful!")
except Exception as e:
    print(f"Neo4j database connection failed: {e}")
# Out:
# Error: Configuration file 'neo4j_config.json' not found. Please create it.
# Neo4j database connection failed: Failed to DNS resolve address your_auradb_instance.databases.neo4j.io:7687: [Errno -2] Name or service not known
# time: 33.8 ms (started: 2026-03-21 11:45:58 +00:00)

# %% [markdown]
# Please create a file named `neo4j_config.json` in your Colab environment with the following content (replace the placeholder values with your actual credentials):

# %% [markdown]
# ```json
# {
#   "uri": "neo4j+s://your_auradb_instance.databases.neo4j.io",
#   "username": "neo4j",
#   "password": "your_auradb_password"
# }
# ```
#
# After creating the file and uploading it (if necessary), please run the cells above.

# %%
def setup_db():
    with driver.session() as session:
        session.run("""
        CREATE CONSTRAINT cache_key IF NOT EXISTS
        FOR (c:Cache) REQUIRE c.key IS UNIQUE
        """)
        session.run("""
        MERGE (a:NPC {name:'arjun'})
        SET a.personality = 'nervous, polite, avoids conflict',
            a.truth = 'I took page 42. Thorne was alive.',
            a.lie = 'The page was damaged',
            a.state = 'COMPOSED'
        """)
        session.run("""
        MERGE (b:NPC {name:'bell'})
        SET b.personality = 'arrogant, intellectual',
            b.truth = 'I visited storage and saw Graves',
            b.lie = 'I never left the hall',
            b.state = 'COMPOSED'
        """)
        session.run("""
        MERGE (g:NPC {name:'graves'})
        SET g.personality = 'calm, controlled',
            g.truth = 'I poisoned the brandy',
            g.lie = 'I stayed in office',
            g.state = 'COMPOSED'
        """)
        session.run("""
        MERGE (e:Evidence {id:'page_42'})
        SET e.description = 'Torn manuscript page',
            e.discovered = false
        """)
# Out:
# time: 1.53 ms (started: 2026-03-21 11:58:28 +00:00)

# %%
import hashlib
from typing import TypedDict, List, Dict
# Out:
# time: 586 µs (started: 2026-03-21 11:58:31 +00:00)

# %%
def get_npc_data(npc):
    with driver.session() as session:
        result = session.run("""
        MATCH (n:NPC {name:$name})
        RETURN n.personality AS personality,
               n.truth AS truth,
               n.lie AS lie,
               n.state AS state
        """, name=npc).single()
        if result is None:
            return {"personality": "unknown", "truth": "", "lie": "", "state": "COMPOSED"}
        return dict(result)
# Out:
# time: 1.24 ms (started: 2026-03-21 11:58:31 +00:00)

# %%
# Out:
# time: 524 ms (started: 2026-03-21 11:58:31 +00:00)

# %%
class GameState(TypedDict):
    player_input: str
    chat_history: List[Dict]
    npc_states: Dict
    evidence: List[str]
    active_npc: str


def get_npc_data(npc):
    with driver.session() as session:
        result = session.run("""
        MATCH (n:NPC {name:$name})
        RETURN n.personality AS personality,
               n.truth AS truth,
               n.lie AS lie,
               n.state AS state
        """, name=npc).single()
        if result is None:
            return {"personality": "unknown", "truth": "", "lie": "", "state": "COMPOSED"}
        return dict(result)



def get_evidence():
    with driver.session() as session:
        result = session.run("""
        MATCH (e:Evidence)
        WHERE e.discovered = true
        RETURN e.id AS id
        """)
        return [r["id"] for r in result]


def update_npc_state(npc, user_input, evidence):
    text = user_input.lower()
    if npc == 'arjun':
        if 'page 42' in text: return 'DEFENSIVE'
        if 'show page 42' in text: return 'BREAKDOWN'
    if npc == 'bell':
        if 'storage' in text: return 'DEFENSIVE'
        if 'vial' in text: return 'BREAKDOWN'
    if npc == 'graves':
        if 'ledger' in text: return 'DEFENSIVE'
        if all(x in text for x in ['ledger','pantry','vial']): return 'BREAKDOWN'
    return 'COMPOSED'



def get_cache(prompt):
    key = hashlib.md5(prompt.encode()).hexdigest()
    with driver.session() as session:
        res = session.run("MATCH (c:Cache {key:$key}) RETURN c.response AS response", key=key).single()
        return res['response'] if res else None

def set_cache(prompt, response):
    key = hashlib.md5(prompt.encode()).hexdigest()
    with driver.session() as session:
        session.run("MERGE (c:Cache {key:key}) SET c.response= response", key=key, response=response)


def build_prompt(npc, state, user_input):
    data = get_npc_data(npc)
    evidence = get_evidence()
    mental = state['npc_states'][npc]
    system_prompt = f"""
    You are {npc}, a murder suspect. Stay in character. Max 2 sentences.
    Personality: {data['personality']}
    Truth: {data['truth']}
    Lie: {data['lie']}
    Mental State: {mental}
    Evidence: {evidence}
    """
    return [
        {'role':'system','content':system_prompt},
        {'role':'user','content':user_input}
    ]

def clean_response(text):
    text = text.strip().split("\n")[0]
    for p in ['arjun:','player:','assistant:','npc:']:
        if text.lower().startswith(p):
            text = text[len(p):].strip()
    return text



def npc_response(state):
    npc = state['active_npc']
    user_input = state['player_input']
    new_state = update_npc_state(npc, user_input, state['evidence'])
    state['npc_states'][npc] = new_state
    messages = build_prompt(npc, state, user_input)
    cache_key = ''.join([m['content'] for m in messages])
    cached = get_cache(cache_key)
    if cached:
        response_text = cached
    else:
        response = conv.invoke(messages)
        response_text = clean_response(response.content)
        set_cache(cache_key, response_text)
    state['chat_history'].append({
        'npc': npc,
        'state': new_state,
        'text': response_text
    })
    return state


def unlock_evidence(evidence_id):
    with driver.session() as session:
        session.run("MATCH (e:Evidence {id:$id}) SET e.discovered=true", id=evidence_id)


def route_npc(user_input):
    text = user_input.lower()
    if 'arjun' in text: return 'arjun'
    if 'bell' in text: return 'bell'
    if 'graves' in text: return 'graves'
    return 'arjun'



def run_game():
    state = {
        'player_input':'',
        'chat_history':[],
        'npc_states':{'arjun':'COMPOSED','bell':'COMPOSED','graves':'COMPOSED'},
        'evidence':[],
        'active_npc':'arjun'
    }
    print("\n🕵️ Welcome to The Shimla Ledger")
    print("Type 'talk arjun', 'talk bell', 'talk graves' to switch NPC")
    print("Type 'exit' to quit")
    while True:
        user_input = input("\nYou: ")
        if user_input.lower() == 'exit': break
        if user_input.startswith('talk'):
            parts = user_input.split(' ')
            if len(parts) > 1:
                state['active_npc'] = parts[1]
                print(f"\n➡️ Now talking to {parts[1]}")
            else:
                print("⚠️ Specify NPC name")
            continue
        state['player_input'] = user_input
        state = npc_response(state)
        last = state['chat_history'][-1]
        print(f"\n{last['npc']} ({last['state']}): {last['text']}")


setup_db()
run_game()
# Out:
# 🕵️ Welcome to The Shimla Ledger
# Type 'talk arjun', 'talk bell', 'talk graves' to switch NPC
# Type 'exit' to quit
#
# You: talk graves
#
# ➡️ Now talking to graves
#
# You: was graves in storage room?
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N52', status_description='warn: property key does not exist. The property `response` does not exist in database `b552bc3b`. Verify that the spelling is correct.', position=<SummaryInputPosition line=1, column=37, offset=36>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 36, 'line': 1, 'column': 37}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'MATCH (c:Cache {key:$key}) RETURN c.response AS response'
# ---------------------------------------------------------------------------
# GqlError                                  Traceback (most recent call last)
# GqlError: {gql_status: 42N62} {gql_status_description: error: syntax error or access rule violation - variable not defined. Variable `key` not defined.} {message: 42N62: Variable `key` not defined.} {diagnostic_record: {'_classification': 'CLIENT_ERROR', '_position': {'offset': 20, 'column': 21, 'line': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}} {raw_classification: CLIENT_ERROR}
#
# The above exception was the direct cause of the following exception:
#
# CypherSyntaxError                         Traceback (most recent call last)
# /tmp/ipykernel_18816/754112615.py in <cell line: 0>()
#     150
#     151 setup_db()
# --> 152 run_game()
#     153
#
# /tmp/ipykernel_18816/754112615.py in run_game()
#     144             continue
#     145         state['player_input'] = user_input
# --> 146         state = npc_response(state)
#     147         last = state['chat_history'][-1]
#     148         print(f"\n{last['npc']} ({last['state']}): {last['text']}")
#
# /tmp/ipykernel_18816/754112615.py in npc_response(state)
#      98         response = conv.invoke(messages)
#      99         response_text = clean_response(response.content)
# --> 100         set_cache(cache_key, response_text)
#     101     state['chat_history'].append({
#     102         'npc': npc,
#
# /tmp/ipykernel_18816/754112615.py in set_cache(prompt, response)
#      56     key = hashlib.md5(prompt.encode()).hexdigest()
#      57     with driver.session() as session:
# ---> 58         session.run("MERGE (c:Cache {key:key}) SET c.response= response", key=key, response=response)
#      59
#      60
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/work/session.py in run(self, query, parameters, **kwargs)
#     318         bookmarks = self._get_bookmarks()
#     319         parameters = dict(parameters or {}, **kwargs)
# --> 320         self._auto_result._run(
#     321             query,
#     322             parameters,
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/work/result.py in _run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     235         self._pull()
#     236         self._connection.send_all()
# --> 237         self._attach()
#     238
#     239     def _pull(self):
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/work/result.py in _attach(self)
#     437         if self._exhausted is False:
#     438             while self._attached is False:
# --> 439                 self._connection.fetch_message()
#     440
#     441     def _buffer(self, n=None):
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_common.py in inner(*args, **kwargs)
#     191             def inner(*args, **kwargs):
#     192                 try:
# --> 193                     func(*args, **kwargs)
#     194                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     195                     assert not inspect.iscoroutinefunction(self.__on_error)
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_bolt.py in fetch_message(self)
#     865             hydration_hooks=self.responses[0].hydration_hooks
#     866         )
# --> 867         res = self._process_message(tag, fields)
#     868         self.idle_since = monotonic()
#     869         return res
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_bolt6.py in _process_message(self, tag, fields)
#     546             self._enrich_error_diagnostic_record(summary_metadata)
#     547             try:
# --> 548                 response.on_failure(summary_metadata or {})
#     549             except (ServiceUnavailable, DatabaseUnavailable):
#     550                 if self.pool:
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_common.py in on_failure(self, metadata)
#     261         handler = self.handlers.get("on_summary")
#     262         Util.callback(handler)
# --> 263         raise self._hydrate_error(metadata)
#     264
#     265     def on_ignored(self, metadata=None):
#
# CypherSyntaxError: {neo4j_code: Neo.ClientError.Statement.SyntaxError} {message: Variable `key` not defined (line 1, column 21 (offset: 20))
# "MERGE (c:Cache {key:key}) SET c.response= response"
#                      ^} {gql_status: 42001} {gql_status_description: error: syntax error or access rule violation - invalid syntax}
# time: 20.3 s (started: 2026-03-21 11:58:31 +00:00)
